# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov3  # clone
# %cd yolov3
# %pip install -qr requirements.txt  # install

import torch
from yolov3 import utils
display = utils.notebook_init()  # checks
# Out:
# Setup complete ✅

# %% [markdown]
# First make the zip file of your data sets containin train and validate forlder.
# The upload the zip file into colab root directory

# %%
# !unzip -q ../train_data.zip -d ../

# %% [markdown]
# # TRAIN Custom model using custom data set

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: wizrehan (wizteam). Use `wandb login --relogin` to force relogin
# True

# %%
# Train YOLOv3 on COCO128 for 80 epochs
# !python train.py --img 640 --batch 20 --epochs 80 --data custom_path.yaml --weights yolov3.pt --cache
# Out:
# wandb: Currently logged in as: wizrehan (wizteam). Use `wandb login --relogin` to force relogin
# train: weights=yolov3.pt, cfg=, data=custom_path.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=80, batch_size=20, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov3 ✅
# YOLOv3 🚀 v9.6.0-24-gb0b071d torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# # Inference
#
# train a custom vedio file where all the object to detect according to test our trained model.

# %%
# !python detect.py --weights runs/train/exp6/weights/last.pt --img 640 --conf 0.80 --source ../test.mp4
# Out:
# detect: weights=['runs/train/exp6/weights/last.pt'], source=../test.mp4, imgsz=[640, 640], conf_thres=0.8, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 v9.6.0-24-gb0b071d torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model Summary: 261 layers, 61497430 parameters, 0 gradients, 154.5 GFLOPs
# video 1/1 (1/1907) /content/test.mp4: 352x640 Done. (0.046s)
# video 1/1 (2/1907) /content/test.mp4: 352x640 Done. (0.044s)
# video 1/1 (3/1907) /content/test.mp4: 352x640 Done. (0.027s)
# video 1/1 (4/1907) /content/test.mp4: 352x640 Done. (0.025s)
# video 1/1 (5/1907) /content/test.mp4: 352x640 Done. (0.026s)
# video 1/1 (6/1907) /content/test.mp4: 352x640 Done. (0.025s)
# ...
